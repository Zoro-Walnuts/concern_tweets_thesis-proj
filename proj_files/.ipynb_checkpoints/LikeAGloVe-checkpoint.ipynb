# %% [markdown]
# # GLOVe-LSA-SVM
# - Uses LSA to capture latent features
# - Uses SVM to find optimal hyperplane of separation
#
# ---
#
# **TODO**
# - Metrics

# %%
## IMPORTS
# LSA
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# SVM
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, ParameterGrid
from sklearn.model_selection import RandomizedSearchCV
import scipy.stats as stats
from joblib import parallel_backend

# GLOVE Embeddings
import spacy

# metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, balanced_accuracy_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
import csv
import chardet
import numpy as np
import re
import pandas as pd
import demoji

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/walnuts/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Load the dataset / read csv
# MAKE SURE CSV IS IN UTF-8 (if tweets have emojis)

## Testing if csv can open (Use for troubleshooting)
# with open('Eng_Tweets.csv') as csv_file:
#   csvFile = csv.reader(csv_file, delimiter=',')
#   for row in csv_file:
#     print(row)

pd.set_option('display.max_colwidth', None)
csv_path = 'Eng_Tweets.csv'

df = pd.read_csv(csv_path)
print("total rows: " + str(len(df)))
df.head() ## head won't show emojis unless using print function
# Out:
# total rows: 2335
#        Username  \
# 0    @fudaishii
# 1  @yourdystiny
# 2      @ocenhxu
# 3  @ifeelgoodto
# 4      @ysuckme
#
#                                                                                                                                                    Tweet  \
# 0                              i'm genuinely going to attempt tonight i can't do this anymore i can't handle all this stress i wish i was never born bro
# 1  Becoming less reactive is a huge part of growth & decreasing stress. If you let everything get you worked up, you’ll damage your mind, body & spirit.
# 2                                                                                       me ??? tired ??? stressed ??? exhausted ??? i wanna cry ??? yes.
# 3                                 skipping meals, irregular sleeping habits, overthinking, stress, tired and drained. that's me, that's my everyday life
# 4                                                                             you deserve to be happy. not confused, not hurt, not stressed, just happy.
#
#   Date posted  Label
# 0     9/11/24    1.0
# 1      9/8/24    0.0
# 2      9/8/24    1.0
# 3     9/10/24    0.0
# 4      9/8/24    0.0

# %% [markdown]
# ## Preprocessing
# - Remove mentions (@)
# - Remove hashtags (#)
# - Remove URLs
# - Replace emojis with textual description (Using demoji)
# - Remove stop words

# %%
### PREPROCESSING STEPS
def clean_text(text):
  # Remove mentions
  text = re.sub(r'@[A-Za-z0-9_]+', '', text)
  # Remove hashtags
  text = re.sub(r'#\w+', '', text)
  # Remove URLs
  text = re.sub(r'http\S+|www\S+|https\S+', '', text)
  # Replace emoji with textual descriptions
  text = demoji.replace_with_desc(text)
  text = re.sub(r'(:[a-zA-Z\s]+:)', r' \1 ', text) # Add spaces around the shortcode
  text = re.sub(r'(:[a-zA-Z\s]+:)', lambda match: match.group(0).replace(' ', '_'), text)
  text = text.strip()
  return text

stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
  words = text.split()
  filtered_words = [word for word in words if word.lower() not in stop_words]
  return ' '.join(filtered_words)

df = df.dropna() # Get rid of NaN rows
df['Tweet'] = df['Tweet'].apply(clean_text)
df['Tweet'] = df['Tweet'].apply(remove_stopwords)

# %%
df.head()
# Out:
#        Username  \
# 0    @fudaishii
# 1  @yourdystiny
# 2      @ocenhxu
# 3  @ifeelgoodto
# 4      @ysuckme
#
#                                                                                                                            Tweet  \
# 0                                      i'm genuinely going attempt tonight can't anymore can't handle stress wish never born bro
# 1  Becoming less reactive huge part growth & decreasing stress. let everything get worked up, you’ll damage mind, body & spirit.
# 2                                                                    ??? tired ??? stressed ??? exhausted ??? wanna cry ??? yes.
# 3                skipping meals, irregular sleeping habits, overthinking, stress, tired drained. that's me, that's everyday life
# 4                                                                                deserve happy. confused, hurt, stressed, happy.
#
#   Date posted  Label
# 0     9/11/24    1.0
# 1      9/8/24    0.0
# 2      9/8/24    1.0
# 3     9/10/24    0.0
# 4      9/8/24    0.0

# %%
df['Label'].value_counts()
# Out:
# Label
# 0.0    1837
# 1.0     496
# Name: count, dtype: int64

# %% [markdown]
# ## GloVe Embeddings
# - Make sure to run "python -m spacy download en_core_web_md"
# - GloVe embeddings are then averaged and standardized
# - Train-Test-Validation split = 70% - 20% - 10%
# - Uses undersampling to balance the training set

# %%
nlp = spacy.load("en_core_web_md", disable=["tagger", "parser", "ner"]) # disable non word-embedding parts of spacy

# Create an empty list to store the embeddings
embeddings = []

# Iterate through the DataFrame
for index, row in df.iterrows():
    tweet = row['Tweet']
    doc = nlp(tweet)

    # Get the embeddings for each token and store them
    tweet_embeddings = [token.vector for token in doc]
    embeddings.append(tweet_embeddings)

# Add the embeddings to the DataFrame as a new column
df['embeddings'] = embeddings
# Out:
# /home/walnuts/projects/tf-gpu/lib/python3.12/site-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
# Function to average embeddings for a tweet
def average_embeddings(embeddings_list):
    if embeddings_list:
        return np.mean(embeddings_list, axis=0)
    else:
        return np.zeros(300)  # 300 = embedding dimenstion

# %%
# Function to split the dataset into train, validation, and test
def split_data(df, train_size=0.7, val_size=0.1, test_size=0.2):
    # 70% into training 30% into validation + testing 
    train_df, temp_df = train_test_split(df, train_size=train_size, random_state=42)
    
    # 30% splits 10% into validation and 20% into testing
    val_df, test_df = train_test_split(temp_df, train_size=val_size / (val_size + test_size), random_state=42)
    
    return train_df, val_df, test_df

# %%
# Average the sentence embedding into a single entry
df['avg_embedding'] = df['embeddings'].apply(average_embeddings)

# Split the dataset
train_df, val_df, test_df = split_data(df)

X_train = np.array(train_df['avg_embedding'].to_list())
y_train = train_df['Label']
X_val = np.array(val_df['avg_embedding'].to_list())
y_val = val_df['Label']
X_test = np.array(test_df['avg_embedding'].to_list())
y_test = test_df['Label']

# # Undersample the training set to balance the classes using RandomUnderSampler
undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

# smote = SMOTE(sampling_strategy='auto', random_state=42)
# X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Optionally, check the class distribution after undersampling
print(f"Class distribution after undersampling:\n{pd.Series(y_train_resampled).value_counts()}")
# Out:
# Class distribution after undersampling:
# Label
# 0.0    354
# 1.0    354
# Name: count, dtype: int64

# %% [markdown]
# ## LSA (Latent Semantic Analysis)
# - Also uses standard scaler for standardization of values

# %%
# Apply LSA (Latent Semantic Analysis) for dimensionality reduction
lsa = TruncatedSVD(n_components=100, random_state=42) 

X_train_lsa = lsa.fit_transform(X_train_resampled)
X_val_lsa = lsa.transform(X_val)
X_test_lsa = lsa.transform(X_test)

# Standardization (scaling)
scaler = StandardScaler()
X_train_final = scaler.fit_transform(X_train_lsa)
X_val = scaler.transform(X_val_lsa)
X_test = scaler.transform(X_test_lsa)

# X_train_final = X_train_lsa
# X_val = X_val_lsa
# X_test = X_test_lsa

# %% [markdown]
# ## SVM (Support Vector Machine)

# %%
# Train the model using SVC
model = SVC(probability=True)
model.fit(X_train_final, y_train_resampled)
# Out:
# SVC(probability=True)

# %%
# Hyperparameter search
# Define the parameter grid to search
param_grid = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'kernel': ['linear', 'rbf', 'poly'],  # Type of kernel
    'gamma': ['scale', 'auto', 0.1, 1],  # Kernel coefficient for 'rbf', 'poly', and 'sigmoid'
    'class_weight': [None, 'balanced'],  # Class weight for handling imbalanced datasets
}

# Define a function to modify the parameter grid for 'degree'
def filter_degree(param_grid):
    # Generate all combinations of the parameter grid
    grid = list(ParameterGrid(param_grid))

    # Filter out invalid combinations where 'degree' is used without 'poly' kernel
    valid_grid = []
    for params in grid:
        if params['kernel'] == 'poly' and 'degree' not in params:
            # Ensure degree is included when using 'poly' kernel
            params['degree'] = [3]  # Default value for degree (as a list)
        elif params['kernel'] != 'poly' and 'degree' in params:
            # Remove degree for non-'poly' kernels
            del params['degree']
        
        # Ensure all parameters are in list format
        for key in params:
            if not isinstance(params[key], list):
                params[key] = [params[key]]

        valid_grid.append(params)
    
    return valid_grid

# Filtered parameter grid based on the kernel
filtered_param_grid = filter_degree(param_grid)

# Initialize the SVC model
svc = SVC(probability=True)

# Set up the GridSearchCV with cross-validation (5-fold cross-validation in this example)
grid_search = GridSearchCV(
    estimator=svc, 
    param_grid=filtered_param_grid, 
    cv=3, 
    n_jobs=-1,
    verbose=2, 
    scoring='accuracy'
)

# Fit the grid search to the training data using parallel backend
with parallel_backend('multiprocessing'):
    grid_search.fit(X_train_final, y_train_resampled)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Print the best results
print(f"Best parameters found: {best_params}")
print(f"Best cross-validation accuracy: {best_score}")
# Out:
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   0.1s[CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   0.1s[CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   0.1s
#
# [CV] END C=0.1, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s[CV] END C=0.1, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s[CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
#
#
#
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s[CV] END C=0.1, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
#
# [CV] END ..C=0.1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=linear; total time=   0.1s[CV] END C=0.1, class_weight=None, gamma=auto, kernel=linear; total time=   0.1s[CV] END C=0.1, class_weight=None, gamma=auto, kernel=linear; total time=   0.1s
#
#
# [CV] END C=0.1, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s[CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
#
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
#
# [CV] END C=0.1, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s[CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END .C=0.1, class_weight=None, gamma=0.1, kernel=linear; total time=   0.1s[CV] END .C=0.1, class_weight=None, gamma=0.1, kernel=linear; total time=   0.1s
# [CV] END .C=0.1, class_weight=None, gamma=0.1, kernel=linear; total time=   0.1s
#
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s[CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
#
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s[CV] END C=0.1, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
#
# [CV] END C=0.1, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END ...C=0.1, class_weight=None, gamma=1, kernel=linear; total time=   0.1s
# [CV] END C=0.1, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s[CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=   0.1s
#
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=   0.1s[CV] END ...C=0.1, class_weight=None, gamma=1, kernel=linear; total time=   0.1s
#
# [CV] END C=0.1, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END ...C=0.1, class_weight=None, gamma=1, kernel=linear; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s[CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s[CV] END C=0.1, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
#
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
#
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=   0.1s[CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
#
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=   0.1s[CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=   0.1s
#
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=1, kernel=linear; total time=   0.1s
#
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s[CV] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s[CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
#
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.2s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=   0.2s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s[CV] END C=0.1, class_weight=balanced, gamma=1, kernel=linear; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
#
# [CV] END C=0.1, class_weight=balanced, gamma=1, kernel=linear; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END ..C=0.1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ....C=1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s[CV] END C=1, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
#
# [CV] END C=1, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END .....C=1, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s[CV] END .....C=1, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
#
# [CV] END ....C=1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END ......C=1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END .....C=1, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END ......C=1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s[CV] END .C=1, class_weight=None, gamma=scale, kernel=linear; total time=   0.6s
#
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   0.5s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...C=1, class_weight=None, gamma=0.1, kernel=linear; total time=   0.6s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s[CV] END C=1, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
#
# [CV] END .....C=1, class_weight=None, gamma=1, kernel=linear; total time=   0.4s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   0.7s
# [CV] END .C=1, class_weight=None, gamma=scale, kernel=linear; total time=   0.8s
# [CV] END .C=1, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END .....C=1, class_weight=None, gamma=1, kernel=linear; total time=   0.6s
# [CV] END .C=1, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ....C=1, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s[CV] END C=1, class_weight=balanced, gamma=scale, kernel=linear; total time=   0.4s
#
# [CV] END ...C=1, class_weight=None, gamma=0.1, kernel=linear; total time=   0.7s
# [CV] END .C=1, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END ......C=1, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=linear; total time=   0.4s
# [CV] END .C=1, class_weight=None, gamma=scale, kernel=linear; total time=   0.6s[CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
#
# [CV] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=linear; total time=   0.7s[CV] END C=1, class_weight=balanced, gamma=auto, kernel=linear; total time=   0.5s
#
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...C=1, class_weight=None, gamma=0.1, kernel=linear; total time=   0.6s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   0.6s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=linear; total time=   0.5s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=linear; total time=   0.6s
# [CV] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END ...C=10, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END .....C=1, class_weight=None, gamma=1, kernel=linear; total time=   0.7s
# [CV] END ...C=10, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ....C=10, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=linear; total time=   0.7s
# [CV] END C=10, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END ....C=10, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=   0.5s
# [CV] END C=10, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s[CV] END ....C=10, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
#
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s[CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=   0.6s
#
# [CV] END C=10, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=linear; total time=   0.8s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=linear; total time=   0.7s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s[CV] END C=10, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
#
# [CV] END C=10, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=   0.7s[CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
#
# [CV] END C=10, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s[CV] END C=10, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
#
# [CV] END C=10, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=linear; total time=   5.4s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   5.4s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   6.1s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ....C=10, class_weight=None, gamma=1, kernel=linear; total time=   6.2s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=   6.3s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=   6.2s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END ....C=10, class_weight=None, gamma=1, kernel=linear; total time=   7.2s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   8.3s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=   7.1s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=   7.9s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=linear; total time=   9.8s
# [CV] END ...C=10, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=linear; total time=   5.2s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=   4.3s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   5.3s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=  11.0s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ..C=100, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ..C=100, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ..C=100, class_weight=None, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=   6.7s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=   6.8s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=linear; total time=   6.9s
# [CV] END ....C=10, class_weight=None, gamma=1, kernel=linear; total time=  10.7s
# [CV] END ...C=100, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ...C=100, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ...C=100, class_weight=None, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=linear; total time=  11.0s
# [CV] END C=100, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=   9.3s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  12.6s
# [CV] END ....C=100, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ....C=100, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END ....C=100, class_weight=None, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=  15.4s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=linear; total time=   9.0s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  55.1s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=   0.2s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 1.1min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 1.3min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=linear; total time= 1.3min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=scale, kernel=poly; total time=   0.1s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 1.2min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=linear; total time= 1.4min
# [CV] END ...C=100, class_weight=None, gamma=1, kernel=linear; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END ...C=100, class_weight=None, gamma=1, kernel=linear; total time= 1.3min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 1.4min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 1.4min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=0.1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=None, gamma=scale, kernel=linear; total time= 1.6min
# [CV] END ...C=100, class_weight=None, gamma=1, kernel=linear; total time= 1.5min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=linear; total time=  45.2s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, degree=3, gamma=1, kernel=poly; total time=   0.1s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=linear; total time=  40.5s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=linear; total time= 1.1min
# [CV] END C=100, class_weight=balanced, gamma=1, kernel=linear; total time=  57.7s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=linear; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=linear; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=auto, kernel=linear; total time= 1.4min
# [CV] END C=100, class_weight=balanced, gamma=auto, kernel=linear; total time= 1.5min
# [CV] END C=100, class_weight=balanced, gamma=1, kernel=linear; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=linear; total time= 1.6min
# [CV] END C=100, class_weight=balanced, gamma=auto, kernel=linear; total time= 1.6min
# [CV] END C=100, class_weight=balanced, gamma=1, kernel=linear; total time= 1.2min
# Best parameters found: {'C': 1, 'class_weight': None, 'gamma': 'scale', 'kernel': 'rbf'}
# Best cross-validation accuracy: 0.7259887005649718

# %%
# Define the parameter distribution to sample from
# param_dist = {
#     'C': stats.uniform(0.1, 10),  # Uniform distribution from 0.1 to 10
#     'kernel': ['linear', 'rbf', 'poly'],  # Type of kernel
#     'gamma': ['scale', 'auto', stats.uniform(0.001, 1)],  # Kernel coefficient
#     'degree': [3, 5, 7],  # Degree for 'poly' kernel
#     'class_weight': [None, 'balanced'],  # Class weight for imbalance
# }

# # Initialize the SVC model
# svc = SVC(probability=True)

# # Set up RandomizedSearchCV with 5-fold cross-validation (number of iterations = 20)
# random_search = RandomizedSearchCV(estimator=svc, param_distributions=param_dist, n_iter=20, cv=5, n_jobs=-1, verbose=1, scoring='accuracy', random_state=42)

# # Fit the random search to the training data
# random_search.fit(X_train_final, y_train_resampled)

# # Get the best parameters and best score
# best_params_random = random_search.best_params_
# best_score_random = random_search.best_score_

# print(f"Best parameters found using RandomizedSearchCV: {best_params_random}")
# print(f"Best cross-validation accuracy: {best_score_random}")

# %%
# Using the best parameters from grid search or random search
# best_model = grid_search.best_estimator_  # or 
best_model = random_search.best_estimator_

# Final evaluation on the test set
y_pred_test = best_model.predict(X_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
print(f"Test Accuracy: {accuracy_test}")
# Out:
# Test Accuracy: 0.7794432548179872

# %%
# Evaluation on validation set
y_pred_val = best_model.predict(X_val)
accuracy_val = accuracy_score(y_val, y_pred_val)
precision_val = precision_score(y_val, y_pred_val)
recall_val = recall_score(y_val, y_pred_val)
f1_val = f1_score(y_val, y_pred_val)
balanced_acc_val = balanced_accuracy_score(y_val, y_pred_val)  # Add balanced accuracy
conf_matrix_val = confusion_matrix(y_val, y_pred_val)

print(f"Validation Accuracy: {accuracy_val}")
print(f"Validation Precision: {precision_val}")
print(f"Validation Recall: {recall_val}")
print(f"Validation F1 Score: {f1_val}")
print(f"Validation Balanced Accuracy: {balanced_acc_val}")  # Print balanced accuracy
print(f"Validation Confusion Matrix: \n{conf_matrix_val}")

# Final evaluation on test set
y_pred_test = best_model.predict(X_test)
accuracy_test = accuracy_score(y_test, y_pred_test)
precision_test = precision_score(y_test, y_pred_test)
recall_test = recall_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
balanced_acc_test = balanced_accuracy_score(y_test, y_pred_test)  # Add balanced accuracy
conf_matrix_test = confusion_matrix(y_test, y_pred_test)

print(f"Test Accuracy: {accuracy_test}")
print(f"Test Precision: {precision_test}")
print(f"Test Recall: {recall_test}")
print(f"Test F1 Score: {f1_test}")
print(f"Test Balanced Accuracy: {balanced_acc_test}")  # Print balanced accuracy
print(f"Test Confusion Matrix: \n{conf_matrix_test}")

# Compute ROC AUC
y_prob_test = best_model.predict_proba(X_test)[:, 1]  # Probabilities for the positive class
roc_auc = roc_auc_score(y_test, y_prob_test)
print(f"Test ROC AUC: {roc_auc}")

# Plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_test)
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Validation Accuracy: 0.7467811158798283
# Validation Precision: 0.4691358024691358
# Validation Recall: 0.7037037037037037
# Validation F1 Score: 0.562962962962963
# Validation Balanced Accuracy: 0.7317401200082765
# Validation Confusion Matrix:
# [[136  43]
#  [ 16  38]]
# Test Accuracy: 0.7794432548179872
# Test Precision: 0.4503311258278146
# Test Recall: 0.7727272727272727
# Test F1 Score: 0.5690376569037657
# Test Balanced Accuracy: 0.7768649556248501
# Test Confusion Matrix:
# [[296  83]
#  [ 20  68]]
# Test ROC AUC: 0.8543565603262174

# %%
# Plot confusion matrix for test set
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Predicted Negative', 'Predicted Positive'], 
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.title('Confusion Matrix - Test Set')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# Plot confusion matrix for validation set
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix_val, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Predicted Negative', 'Predicted Positive'], 
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.title('Confusion Matrix - Validation Set')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
